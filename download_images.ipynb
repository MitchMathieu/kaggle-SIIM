# %% [markdown]
# # Downloading Images
# This is a script for downloading the data, provided in the kaggle competition rules

# %%
"""Script to download all instances in a DICOM Store."""
import os
import posixpath
from concurrent import futures
from retrying import retry
import google.auth
from google.auth.transport.requests import AuthorizedSession

# %%
# URL of CHC API
CHC_API_URL = 'https://healthcare.googleapis.com/v1beta1'
PROJECT_ID = 'kaggle-siim-healthcare'
REGION = 'us-central1'
DATASET_ID = 'siim-pneumothorax'
TRAIN_DICOM_STORE_ID = 'dicom-images-train'
TEST_DICOM_STORE_ID = 'dicom-images-test'

# %%
@retry(wait_exponential_multiplier=1000, wait_exponential_max=10000)
def download_instance(dicom_web_url, dicom_store_id, study_uid, series_uid,
                      instance_uid, credentials):
    """Downloads a DICOM instance and saves it under the current folder."""
    instance_url = posixpath.join(dicom_web_url, 'studies', study_uid, 'series',
                                  series_uid, 'instances', instance_uid)
    authed_session = AuthorizedSession(credentials)
    response = authed_session.get(
        instance_url, headers={'Accept': 'application/dicom; transfer-syntax=*'})
    file_path = posixpath.join(dicom_store_id, study_uid, series_uid,
                               instance_uid)
    filename = '%s.dcm' % file_path
    if not os.path.exists(filename):
        os.makedirs(os.path.dirname(filename))
    with open(filename, 'wb') as f:
        f.write(response.content)

# %%
def download_all_instances(dicom_store_id, credentials):
    """Downloads all DICOM instances in the specified DICOM store."""
    # Get a list of all instances.
    dicom_web_url = posixpath.join(CHC_API_URL, 'projects', PROJECT_ID,
                                   'locations', REGION, 'datasets', DATASET_ID,
                                   'dicomStores', dicom_store_id, 'dicomWeb')
    qido_url = posixpath.join(dicom_web_url, 'instances')
    authed_session = AuthorizedSession(credentials)
    response = authed_session.get(qido_url, params={'limit': '15000'})
    if response.status_code != 200:
        print(response.text)
        return
    content = response.json()
    # DICOM Tag numbers
    study_instance_uid_tag = '0020000D'
    series_instance_uid_tag = '0020000E'
    sop_instance_uid_tag = '00080018'
    value_key = 'Value'
    with futures.ThreadPoolExecutor() as executor:
        future_to_study_uid = {}
        for instance in content:
            study_uid = instance[study_instance_uid_tag][value_key][0]
            series_uid = instance[series_instance_uid_tag][value_key][0]
            instance_uid = instance[sop_instance_uid_tag][value_key][0]
            future = executor.submit(download_instance, dicom_web_url, dicom_store_id,
                                     study_uid, series_uid, instance_uid, credentials)
            future_to_study_uid[future] = study_uid
        processed_count = 0
        for future in futures.as_completed(future_to_study_uid):
            try:
                future.result()
                processed_count += 1
                if not processed_count % 100 or processed_count == len(content):
                    print('Processed instance %d out of %d' %
                          (processed_count, len(content)))
            except Exception as e:
                print('Failed to download a study. UID: %s \n exception: %s' %
                      (future_to_study_uid[future], e))

# %%
def main(argv=None):
    credentials, _ = google.auth.default()
    print('Downloading all instances in %s DICOM store' % TRAIN_DICOM_STORE_ID)
    download_all_instances(TRAIN_DICOM_STORE_ID, credentials)
    print('Downloading all instances in %s DICOM store' % TEST_DICOM_STORE_ID)
    download_all_instances(TEST_DICOM_STORE_ID, credentials)

# %%
main()
# Out:
# /usr/local/lib/python3.7/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# Downloading all instances in dicom-images-train DICOM store
# Processed instance 100 out of 10712
# Processed instance 200 out of 10712
# Processed instance 300 out of 10712
# Processed instance 400 out of 10712
# Processed instance 500 out of 10712
# Processed instance 600 out of 10712
# Processed instance 700 out of 10712
# Processed instance 800 out of 10712
# Processed instance 900 out of 10712
# Processed instance 1000 out of 10712
# Processed instance 1100 out of 10712
# Processed instance 1200 out of 10712
# Processed instance 1300 out of 10712
# Processed instance 1400 out of 10712
# Processed instance 1500 out of 10712
# Processed instance 1600 out of 10712
# Processed instance 1700 out of 10712
# Processed instance 1800 out of 10712
# Processed instance 1900 out of 10712
# Processed instance 2000 out of 10712
# Processed instance 2100 out of 10712
# Processed instance 2200 out of 10712
# Processed instance 2300 out of 10712
# Processed instance 2400 out of 10712
# Processed instance 2500 out of 10712
# Processed instance 2600 out of 10712
# Processed instance 2700 out of 10712
# Processed instance 2800 out of 10712
# Processed instance 2900 out of 10712
# Processed instance 3000 out of 10712
# Processed instance 3100 out of 10712
# Processed instance 3200 out of 10712
# Processed instance 3300 out of 10712
# Processed instance 3400 out of 10712
# Processed instance 3500 out of 10712
# Processed instance 3600 out of 10712
# Processed instance 3700 out of 10712
# Processed instance 3800 out of 10712
# Processed instance 3900 out of 10712
# Processed instance 4000 out of 10712
# Processed instance 4100 out of 10712
# Processed instance 4200 out of 10712
# Processed instance 4300 out of 10712
# Processed instance 4400 out of 10712
# Processed instance 4500 out of 10712
# Processed instance 4600 out of 10712
# Processed instance 4700 out of 10712
# Processed instance 4800 out of 10712
# Processed instance 4900 out of 10712
# Processed instance 5000 out of 10712
# Processed instance 5100 out of 10712
# Processed instance 5200 out of 10712
# Processed instance 5300 out of 10712
# Processed instance 5400 out of 10712
# Processed instance 5500 out of 10712
# Processed instance 5600 out of 10712
# Processed instance 5700 out of 10712
# Processed instance 5800 out of 10712
# Processed instance 5900 out of 10712
# Processed instance 6000 out of 10712
# Processed instance 6100 out of 10712
# Processed instance 6200 out of 10712
# Processed instance 6300 out of 10712
# Processed instance 6400 out of 10712
# Processed instance 6500 out of 10712
# Processed instance 6600 out of 10712
# Processed instance 6700 out of 10712
# Processed instance 6800 out of 10712
# Processed instance 6900 out of 10712
# Processed instance 7000 out of 10712
# Processed instance 7100 out of 10712
# Processed instance 7200 out of 10712
# Processed instance 7300 out of 10712
# Processed instance 7400 out of 10712
# Processed instance 7500 out of 10712
# Processed instance 7600 out of 10712
# Processed instance 7700 out of 10712
# Processed instance 7800 out of 10712
# Processed instance 7900 out of 10712
# Processed instance 8000 out of 10712
# Processed instance 8100 out of 10712
# Processed instance 8200 out of 10712
# Processed instance 8300 out of 10712
# Processed instance 8400 out of 10712
# Processed instance 8500 out of 10712
# Processed instance 8600 out of 10712
# Processed instance 8700 out of 10712
# Processed instance 8800 out of 10712
# Processed instance 8900 out of 10712
# Processed instance 9000 out of 10712
# Processed instance 9100 out of 10712
# Processed instance 9200 out of 10712
# Processed instance 9300 out of 10712
# Processed instance 9400 out of 10712
# Processed instance 9500 out of 10712
# Processed instance 9600 out of 10712
# Processed instance 9700 out of 10712
# Processed instance 9800 out of 10712
# Processed instance 9900 out of 10712
# Processed instance 10000 out of 10712
# Processed instance 10100 out of 10712
# Processed instance 10200 out of 10712
# Processed instance 10300 out of 10712
# Processed instance 10400 out of 10712
# Processed instance 10500 out of 10712
# Processed instance 10600 out of 10712
# Processed instance 10700 out of 10712
# Processed instance 10712 out of 10712
# Downloading all instances in dicom-images-test DICOM store
# Processed instance 100 out of 1377
# Processed instance 200 out of 1377
# Processed instance 300 out of 1377
# Processed instance 400 out of 1377
# Processed instance 500 out of 1377
# Processed instance 600 out of 1377
# Processed instance 700 out of 1377
# Processed instance 800 out of 1377
# Processed instance 900 out of 1377
# Processed instance 1000 out of 1377
# Processed instance 1100 out of 1377
# Processed instance 1200 out of 1377
# Processed instance 1300 out of 1377
# Processed instance 1377 out of 1377
